# %%
from src.utils import sanitize
import pandas as pd
import rdkit
from rdkit import Chem

# %%
def make_starter_target_csvs(name2smi, fn, header=['id', 'smiles'], save_dir='../data/starters_targets/'):
    names = list(name2smi.keys())
    smis = sanitize(list(name2smi.values()))
    data = list(zip(names, smis))
    df = pd.DataFrame(data=data, columns=header)
    df.to_csv(save_dir + fn, sep=',', index=False)

# %%
# Methylene molecules

name2smi = {'2-methyleneglutarate': 'C=C(C([O-])=O)CCC(=O)[O-]',
            '4-methylene-l-glutamate': 'C=C(C[C@H]([NH3+])C([O-])=O)C(=O)[O-]'}
fn = 'methylene_molecules.csv'

make_starter_target_csvs(name2smi, fn)

# %%
# CCM

name2smi = {'succinate': 'C(CC(=O)[O-])C(=O)[O-]',
            'fumarate': 'C(=CC(=O)[O-])C(=O)[O-]',
            'malate': 'O=C([O-])C[C@H](O)C(=O)[O-]',
            'oxaloacetate': 'O=C([O-])CC(=O)C(=O)[O-]',
            'ketoglutarate': 'O=C([O-])CCC(=O)C(=O)[O-]',
            'citrate': 'O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-]',
            'pyruvate': 'CC(=O)C(=O)[O-]',
            'acetate': 'CC(=O)[O-]'}

fn = 'ccm_v0.csv'

make_starter_target_csvs(name2smi, fn)

# %%
# Older smis


dvl_smi = 'C1(CCCCO1)=O' # 'dvl'
mvl_smi = 'C1(C(CCCO1)=C)=O' # 'mvl'
succ_smi = 'C(CC(=O)[O-])C(=O)[O-]' # 'succinate'
target_smi = 'C(CCC(C(O[H])=O)=C)O[H]' # 'mvacid'

# %%
# CHPD target

fn = 'chpd.csv'
name2smi = {'chpd' : 'C=C(C-C(C(=O)O)O)C(=O)O'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['chpd'])

# %%
# 2-oxohydroxypentanoic acid

fn = 'hopa.csv'
name2smi = {'hopa' : 'C(CC(=O)C(=O)O)CO'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['hopa'])

# %%
# 2-methyleneglutarate

fn = '2mg.csv'
name2smi = {'2mg' : 'C=C(C(O)=O)CCC(=O)O'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['2mg'])

# %%
# alpha-ketoglutarate

fn = 'alpha_ketoglutarate.csv'
name2smi = {'alpha_ketoglutarate' : 'O=C(O)CCC(=O)C(=O)O'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['alpha_ketoglutarate'])

# %%
# 2-oxopentanoic acid

fn = '2_oxopentanoic_acid.csv'
name2smi = {'2_oxopentanoic_acid' : 'C(CC(=O)C(=O)O)C'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['2_oxopentanoic_acid'])

# %%
# xylose
fn = 'xylose.csv'
name2smi = {'xylose' : 'OCC(O)C(O)C(O)C(=O)'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['xylose'])

# %%
# alpha-ketoglutarate semialdehyde

fn = 'alpha_ketoglutarate_semialdehyde.csv'
name2smi = {'alpha_ketoglutarate' : 'O=CCCC(=O)C(=O)O'}
make_starter_target_csvs(name2smi, fn)
Chem.MolFromSmiles(name2smi['alpha_ketoglutarate'])
